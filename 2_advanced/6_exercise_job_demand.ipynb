# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt


dataset = load_dataset('lukebarousse/data_jobs')


df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_Norge = df[df['job_country']== 'Norway'].copy()

# %%
df_Norge
# Out:
#              job_title_short  \
# 1259           Data Engineer
# 1266        Business Analyst
# 1503           Data Engineer
# 1588    Senior Data Engineer
# 1881            Data Analyst
# ...                      ...
# 783600      Business Analyst
# 783819     Software Engineer
# 784542     Software Engineer
# 784556         Data Engineer
# 785402     Software Engineer
#
#                                                 job_title       job_location  \
# 1259                                        Data Engineer  Stavanger, Norway
# 1266    Production Planner / Business Analyst and Data...       Oslo, Norway
# 1503              Konsulent Data Engineer og Data Analyst    Sandnes, Norway
# 1588                                 Senior Data Engineer  Stavanger, Norway
# 1881              Junior Data Analyst Digital Sales, Oslo       Oslo, Norway
# ...                                                   ...                ...
# 783600                 Pipeline and Spool Design Engineer  Stavanger, Norway
# 783819                         Engineer - Python - Bergen     Bergen, Norway
# 784542  Staff Vulkan Graphics Performance Analysis Eng...       Oslo, Norway
# 784556                               Data Engineer - Oslo       Oslo, Norway
# 785402                                    Senior Engineer       Oslo, Norway
#
#                      job_via job_schedule_type  job_work_from_home  \
# 1259            via LinkedIn         Full-time               False
# 1266         via Jobbland.se         Full-time               False
# 1503            via LinkedIn         Full-time               False
# 1588            via LinkedIn         Full-time               False
# 1881    via Jobs Trabajo.org         Full-time               False
# ...                      ...               ...                 ...
# 783600       via Trabajo.org         Full-time               False
# 783819        via Technojobs         Full-time               False
# 784542             via BeBee         Full-time               False
# 784556        via Technojobs         Full-time               False
# 785402  via Jobs Trabajo.org         Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 1259            Norway 2023-04-14 13:57:36                   True
# 1266            Norway 2023-03-24 13:23:10                  False
# 1503            Norway 2023-06-27 14:21:45                   True
# 1588            Norway 2023-11-30 13:31:12                  False
# 1881            Norway 2023-05-31 13:33:57                  False
# ...                ...                 ...                    ...
# 783600          Norway 2023-08-03 06:54:21                  False
# 783819          Norway 2023-01-29 06:57:46                   True
# 784542          Norway 2023-08-28 06:28:10                  False
# 784556          Norway 2023-01-15 06:28:52                   True
# 785402          Norway 2023-02-27 06:29:11                  False
#
#         job_health_insurance job_country salary_rate  salary_year_avg  \
# 1259                   False      Norway        None              NaN
# 1266                   False      Norway        None              NaN
# 1503                   False      Norway        None              NaN
# 1588                   False      Norway        None              NaN
# 1881                   False      Norway        None              NaN
# ...                      ...         ...         ...              ...
# 783600                 False      Norway        None              NaN
# 783819                 False      Norway        None              NaN
# 784542                 False      Norway        None              NaN
# 784556                 False      Norway        None              NaN
# 785402                 False      Norway        None              NaN
#
#         salary_hour_avg               company_name  \
# 1259                NaN           StaffHost Europe
# 1266                NaN     Nordea Bank Sverige AB
# 1503                NaN              Fraktal Norge
# 1588                NaN                  Capgemini
# 1881                NaN                Nordea Bank
# ...                 ...                        ...
# 783600              NaN                   Subsea 7
# 783819              NaN  Nigel Frank International
# 784542              NaN                arm limited
# 784556              NaN  Nigel Frank International
# 785402              NaN                   Subsea 7
#
#                                                job_skills  \
# 1259    ['sql', 'perl', 'python', 'java', 'mysql', 'or...
# 1266    ['sql', 'excel', 'powerpoint', 'power bi', 'pl...
# 1503                                                 None
# 1588    ['azure', 'aws', 'gcp', 'databricks', 'snowfla...
# 1881    ['python', 'r', 'sql', 'snowflake', 'pyspark',...
# ...                                                   ...
# 783600                               ['matlab', 'python']
# 783819     ['sql', 'nosql', 'aws', 'azure', 'kubernetes']
# 784542                                               None
# 784556         ['python', 'azure', 'aws', 'gcp', 'kafka']
# 785402                            ['python', 'vba', 'go']
#
#                                           job_type_skills
# 1259    {'cloud': ['oracle', 'azure'], 'databases': ['...
# 1266    {'analyst_tools': ['excel', 'powerpoint', 'pow...
# 1503                                                 None
# 1588    {'analyst_tools': ['tableau'], 'cloud': ['azur...
# 1881    {'analyst_tools': ['power bi'], 'cloud': ['sno...
# ...                                                   ...
# 783600              {'programming': ['matlab', 'python']}
# 783819  {'cloud': ['aws', 'azure'], 'other': ['kuberne...
# 784542                                               None
# 784556  {'cloud': ['azure', 'aws', 'gcp'], 'libraries'...
# 785402           {'programming': ['python', 'vba', 'go']}
#
# [1692 rows x 17 columns]

# %%
df_Norge['job_posted_month'] = df_Norge['job_posted_date'].dt.strftime('%B')

df_Norge
# Out:
#              job_title_short  \
# 1259           Data Engineer
# 1266        Business Analyst
# 1503           Data Engineer
# 1588    Senior Data Engineer
# 1881            Data Analyst
# ...                      ...
# 783600      Business Analyst
# 783819     Software Engineer
# 784542     Software Engineer
# 784556         Data Engineer
# 785402     Software Engineer
#
#                                                 job_title       job_location  \
# 1259                                        Data Engineer  Stavanger, Norway
# 1266    Production Planner / Business Analyst and Data...       Oslo, Norway
# 1503              Konsulent Data Engineer og Data Analyst    Sandnes, Norway
# 1588                                 Senior Data Engineer  Stavanger, Norway
# 1881              Junior Data Analyst Digital Sales, Oslo       Oslo, Norway
# ...                                                   ...                ...
# 783600                 Pipeline and Spool Design Engineer  Stavanger, Norway
# 783819                         Engineer - Python - Bergen     Bergen, Norway
# 784542  Staff Vulkan Graphics Performance Analysis Eng...       Oslo, Norway
# 784556                               Data Engineer - Oslo       Oslo, Norway
# 785402                                    Senior Engineer       Oslo, Norway
#
#                      job_via job_schedule_type  job_work_from_home  \
# 1259            via LinkedIn         Full-time               False
# 1266         via Jobbland.se         Full-time               False
# 1503            via LinkedIn         Full-time               False
# 1588            via LinkedIn         Full-time               False
# 1881    via Jobs Trabajo.org         Full-time               False
# ...                      ...               ...                 ...
# 783600       via Trabajo.org         Full-time               False
# 783819        via Technojobs         Full-time               False
# 784542             via BeBee         Full-time               False
# 784556        via Technojobs         Full-time               False
# 785402  via Jobs Trabajo.org         Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 1259            Norway 2023-04-14 13:57:36                   True
# 1266            Norway 2023-03-24 13:23:10                  False
# 1503            Norway 2023-06-27 14:21:45                   True
# 1588            Norway 2023-11-30 13:31:12                  False
# 1881            Norway 2023-05-31 13:33:57                  False
# ...                ...                 ...                    ...
# 783600          Norway 2023-08-03 06:54:21                  False
# 783819          Norway 2023-01-29 06:57:46                   True
# 784542          Norway 2023-08-28 06:28:10                  False
# 784556          Norway 2023-01-15 06:28:52                   True
# 785402          Norway 2023-02-27 06:29:11                  False
#
#         job_health_insurance job_country salary_rate  salary_year_avg  \
# 1259                   False      Norway        None              NaN
# 1266                   False      Norway        None              NaN
# 1503                   False      Norway        None              NaN
# 1588                   False      Norway        None              NaN
# 1881                   False      Norway        None              NaN
# ...                      ...         ...         ...              ...
# 783600                 False      Norway        None              NaN
# 783819                 False      Norway        None              NaN
# 784542                 False      Norway        None              NaN
# 784556                 False      Norway        None              NaN
# 785402                 False      Norway        None              NaN
#
#         salary_hour_avg               company_name  \
# 1259                NaN           StaffHost Europe
# 1266                NaN     Nordea Bank Sverige AB
# 1503                NaN              Fraktal Norge
# 1588                NaN                  Capgemini
# 1881                NaN                Nordea Bank
# ...                 ...                        ...
# 783600              NaN                   Subsea 7
# 783819              NaN  Nigel Frank International
# 784542              NaN                arm limited
# 784556              NaN  Nigel Frank International
# 785402              NaN                   Subsea 7
#
#                                                job_skills  \
# 1259    ['sql', 'perl', 'python', 'java', 'mysql', 'or...
# 1266    ['sql', 'excel', 'powerpoint', 'power bi', 'pl...
# 1503                                                 None
# 1588    ['azure', 'aws', 'gcp', 'databricks', 'snowfla...
# 1881    ['python', 'r', 'sql', 'snowflake', 'pyspark',...
# ...                                                   ...
# 783600                               ['matlab', 'python']
# 783819     ['sql', 'nosql', 'aws', 'azure', 'kubernetes']
# 784542                                               None
# 784556         ['python', 'azure', 'aws', 'gcp', 'kafka']
# 785402                            ['python', 'vba', 'go']
#
#                                           job_type_skills job_posted_month
# 1259    {'cloud': ['oracle', 'azure'], 'databases': ['...            April
# 1266    {'analyst_tools': ['excel', 'powerpoint', 'pow...            March
# 1503                                                 None             June
# 1588    {'analyst_tools': ['tableau'], 'cloud': ['azur...         November
# 1881    {'analyst_tools': ['power bi'], 'cloud': ['sno...              May
# ...                                                   ...              ...
# 783600              {'programming': ['matlab', 'python']}           August
# 783819  {'cloud': ['aws', 'azure'], 'other': ['kuberne...          January
# 784542                                               None           August
# 784556  {'cloud': ['azure', 'aws', 'gcp'], 'libraries'...          January
# 785402           {'programming': ['python', 'vba', 'go']}         February
#
# [1692 rows x 18 columns]

# %%
df_Norge_pivot = df_Norge.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# %%
df_Norge_pivot.reset_index(inplace=True)
df_Norge_pivot['month_no'] = pd.to_datetime(df_Norge_pivot['job_posted_month'], format='%B').dt.month

# %%
df_Norge_pivot.sort_values('month_no',inplace = True)
df_Norge_pivot.set_index('job_posted_month', inplace = True)
df_Norge_pivot.drop(columns='month_no',inplace = True)
df_Norge_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                       16.0             5.0          20.0
# February                      18.0            11.0          27.0
# March                         12.0             6.0          16.0
# April                         22.0             7.0          17.0
# May                           10.0             2.0          23.0
# June                          22.0             2.0          15.0
# July                          12.0             1.0          19.0
# August                        26.0            19.0          19.0
# September                     11.0             3.0          16.0
# October                        7.0             3.0          28.0
# November                       9.0             2.0          18.0
# December                       3.0             NaN           7.0
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    57.0            60.0                        6.0
# February                   39.0            33.0                        1.0
# March                      38.0            31.0                        6.0
# April                      43.0            24.0                        5.0
# May                        35.0            31.0                        1.0
# June                       44.0            23.0                        4.0
# July                       28.0            13.0                        2.0
# August                     31.0            45.0                        6.0
# September                  31.0            21.0                        2.0
# October                    32.0            23.0                        2.0
# November                   52.0            27.0                        6.0
# December                   31.0            23.0                        2.0
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                           5.0                  16.0
# February                          7.0                  15.0
# March                             4.0                   4.0
# April                             2.0                   4.0
# May                               5.0                   6.0
# June                              1.0                  10.0
# July                              NaN                  10.0
# August                            8.0                   8.0
# September                         1.0                   6.0
# October                           2.0                  12.0
# November                          NaN                   5.0
# December                          4.0                   2.0
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# January                            14.0               21.0
# February                           14.0               22.0
# March                               4.0               22.0
# April                               6.0               18.0
# May                                 5.0                6.0
# June                                9.0               15.0
# July                                3.0                6.0
# August                             10.0               35.0
# September                           2.0                7.0
# October                             2.0                9.0
# November                            6.0                4.0
# December                            2.0                1.0

# %%
df_Norge_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_3 = df_Norge['job_title_short'].value_counts().head(3)
top_3 = top_3.index.tolist()

# %%
df_Norge_pivot[top_3].plot(kind='line')
plt.title('Job Postings in Norway by Month')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
# Out:
# Text(0, 0.5, 'Number of Job Postings')
